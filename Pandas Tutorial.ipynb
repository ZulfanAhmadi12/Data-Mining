# %% [markdown]
# ### Loading Data Into Pandas

# %%
import pandas as pd

#poke = pd.read_csv('Pokemon_data.csv')

# poke_xlsx = pd.read.excel('pokemon.xlsx')
poke_text = pd.read_csv('university_towns.txt', delimiter='\n')

#print(poke_text.head(10))
poke_text.head(20)
# Out:
#                                         Alabama[edit]
# 0                       Auburn (Auburn University)[1]
# 1              Florence (University of North Alabama)
# 2     Jacksonville (Jacksonville State University)[2]
# 3          Livingston (University of West Alabama)[2]
# 4            Montevallo (University of Montevallo)[2]
# 5                           Troy (Troy University)[2]
# 6   Tuscaloosa (University of Alabama, Stillman Co...
# 7                   Tuskegee (Tuskegee University)[5]
# 8                                        Alaska[edit]
# 9       Fairbanks (University of Alaska Fairbanks)[2]
# 10                                      Arizona[edit]
# 11         Flagstaff (Northern Arizona University)[6]
# 12                   Tempe (Arizona State University)
# 13                     Tucson (University of Arizona)
# 14                                     Arkansas[edit]
# 15  Arkadelphia (Henderson State University, Ouach...
# ...

# %% [markdown]
# ### Reading data in Pandas

# %%
 ## Read Headers
#print(poke.columns)

## Read each column
#print(poke[['Name','Type 1','Attack']][0:5])

## Read Each Row
#print(poke.iloc[0:4])

#for index, row in poke.iterrows():
#    print(index, row['Name'])

poke.loc[poke['HP'] == 39]

## Read a specific location (R,C)
#print(poke.iloc[2,1])
# Out:
#        #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander   Fire    NaN  39      52       43       60       50
# 169  155   Cyndaquil   Fire    NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  Total
# 4       65           1      False    309
# 169     65           2      False    309

# %% [markdown]
# ### Sorting/Describing Data

# %%
#poke.sort_values(['HP','Attack'], ascending=[1,1])
#poke.describe()
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### Making Changes to the Data

# %%
#this is for making a Total column 
#poke['Total'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Atk'] + poke['Sp. Def'] + poke['Speed']

#this is for deleting Total column
#poke = poke.drop(columns=['Total'])

#this is for making Total column with sum(perjumlahan) dari index 4 sampai 10
poke['Total'] = poke.iloc[:,4:10].sum(axis=1)

#this is for changing the place for Total column with viewing the data
#cols = list(poke.columns.values)
#poke = poke[cols[0:4] +[cols[-1]]+ cols[4:12]]

poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ### Saving our Data (Exporting into Desired Format)

# %%
#poke.to_csv('modified.csv')
#poke.to_excel('modified.xlsx', index=False)
#poke.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ### Filtering Data

# %%
# poke.loc[poke['Type 1']=='Grass']
import re

#this is for locate Type 1 Column with Grass value and Type 2 column with Poison Value and HP column with value more than 70
#new_poke = poke.loc[(poke['Type 1']=='Grass') & (poke['Type 2']=='Poison') &(poke['HP'] > 70)]
#new_poke

# new_poke.to_csv('filtered.csv')
#this is to loc string values in Name columns which contain Mega
#poke.loc[(poke['Name'].str.contains('Mega')) & (poke['Type 1']=='Fire')]
#poke.loc[poke['Type 1'].str.contains('Fire|Grass', regex=True)]

#to get all values in column Name with the beginning of String with PI
poke.loc[poke['Name'].str.contains('^pi[a-z]*',flags=re.I, regex=True)]


#this is to loc string values in Name columns which do not contain Mega
#poke.loc[~poke['Name'].str.contains('Mega')]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
# if you want to reset the index after filtering some data, drop=True for deleting the former index, and inplace=True is to save the change into the new_poke when you dont need to reset into a new dataframe to conserve a little bit memory
# new_poke = new_poke.reset_index(drop=True, inplace=True)
new_poke.reset_index(drop=True, inplace=True)
new_poke
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-854f4b3f57e8> in <module>
#       1 # if you want to reset the index after filtering some data, drop=True for deleting the former index, and inplace=True is to save the change into the new_poke when you dont need to reset into a new dataframe to conserve a little bit memory
#       2 # new_poke = new_poke.reset_index(drop=True, inplace=True)
# ----> 3 new_poke.reset_index(drop=True, inplace=True)
#       4 new_poke
#
# NameError: name 'new_poke' is not defined

# %% [markdown]
# Conditional Changes

# %%
#changing Fire value in Type 1 column itu Flamer
#poke.loc[poke['Type 1']== 'Fire', 'Type 1'] = 'Flamer'
#poke.loc[poke['Type 1']== 'Flamer', 'Type 1'] = 'Fire'

#to change the value in Legendary column into True if the type is Fire
#poke.loc[poke['Type 1'] == 'Fire', 'Legendary'] = True

#to change the value in multiple column at the same time
#poke.loc[poke['Total']> 500,['Generation','Legendary']] = ['Test2','Test1']

poke

# %%
#to re load the data before change the legendary column value
poke = pd.read_csv('modified.csv')
poke

# %% [markdown]
# ### Aggregate Statistics (Groupby)

# %%
#Untuk Melihat nilai rata-rata dari setiap nilai ni kolum Type 1
#poke.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)

poke['count'] = 1
#poke.groupby(['Type 1']).count()['count']
poke.groupby(['Type 1','Type 2']).count()['count']

# %% [markdown]
# ### Working with large amounts of data

# %%
#pass in data with 5rows at a time according to the number of ChunkSize
#for poke in pd.read_csv('modified.csv', chunksize=5):
   # print("CHUNK DF")
    #print(poke)

new_poke = pd.DataFrame(columns=poke.columns)
for poke in pd.read_csv('modified.csv', chunksize=3):
    results = poke.groupby(['Type 1']).count()
    
    new_poke = pd.concat([new_poke, results])
    print('Chunkz')
    print(new_poke)
